# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path_to_preprocessed_image = "/home/andrewheschl/Documents/Datasets/CardiacPipeline/preprocessed/Dataset_010/fold_0/train/case_00001.npy"
preprocessed_img = np.load(path_to_preprocessed_image)

# %%
preprocessed_img.shape
# Out:
# (3, 159, 318)

# %%
plt.imshow(preprocessed_img.transpose(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print(preprocessed_img.min())
print(preprocessed_img.max())
# Out:
# -1.0
# 1.0
