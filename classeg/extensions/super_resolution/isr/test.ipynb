# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('/home/student/andrewheschl/Documents/Datasets/ClassificationDataset/results/Dataset_420/fold_0/gan_with_schedule/inference/x0_0_im.png')
lr_img = np.array(img)

# %%
plt.imshow(lr_img)

# %%
from ISR.models import RDN

lr_img = lr_img[:, :, 0:3]
print(lr_img.shape)
rdn = RDN(weights='psnr-small')
sr_img = rdn.predict(lr_img)
Image.fromarray(sr_img)
# Out:
# (128, 128, 3)
# 2024-07-04 14:10:35.791780: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at xla_ops.cc:580 : NOT_FOUND: Couldn't find ptxas. The following locations were considered: ./cuda_sdk_lib/bin/ptxas, /home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/bin/ptxas, /home/student/andrewheschl/anaconda3/bin/ptxas, /home/student/andrewheschl/anaconda3/condabin/ptxas, /usr/local/sbin/ptxas, /usr/local/bin/ptxas, /usr/sbin/ptxas, /usr/bin/ptxas, /sbin/ptxas, /bin/ptxas, /usr/games/ptxas, /usr/local/games/ptxas, /snap/bin/ptxas, /usr/local/cuda-12.3/bin/ptxas, /usr/local/cuda/bin/ptxas, /home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc/bin/ptxas, /home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/tensorflow/python/platform/../../../../nvidia/cuda_nvcc/bin/ptxas
# 2024-07-04 14:10:35.791816: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: NOT_FOUND: Couldn't find ptxas. The following locations were considered: ./cuda_sdk_lib/bin/ptxas, /home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/bin/ptxas, /home/student/andrewheschl/anaconda3/bin/ptxas, /home/student/andrewheschl/anaconda3/condabin/ptxas, /usr/local/sbin/ptxas, /usr/local/bin/ptxas, /usr/sbin/ptxas, /usr/bin/ptxas, /sbin/ptxas, /bin/ptxas, /usr/games/ptxas, /usr/local/games/ptxas, /snap/bin/ptxas, /usr/local/cuda-12.3/bin/ptxas, /usr/local/cuda/bin/ptxas, /home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc/bin/ptxas, /home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/tensorflow/python/platform/../../../../nvidia/cuda_nvcc/bin/ptxas
# 	 [[{{node StatefulPartitionedCall}}]]
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[17], line 6
#       4 print(lr_img.shape)
#       5 rdn = RDN(weights='psnr-small')
# ----> 6 sr_img = rdn.predict(lr_img)
#       7 Image.fromarray(sr_img)
#
# File ~/image-super-resolution/ISR/models/imagemodel.py:59, in ImageModel.predict(self, input_image_array, by_patch_of_size, batch_size, padding_size)
#      57 else:
#      58     lr_img = process_array(input_image_array)
# ---> 59     sr_img = self.model.predict(lr_img)[0]
#      61 sr_img = process_output(sr_img)
#      62 return sr_img
#
# File ~/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# NotFoundError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 739, in start
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 205, in start
#
#   File "/home/student/andrewheschl/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#
#   File "/home/student/andrewheschl/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#
#   File "/home/student/andrewheschl/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#
#   File "/tmp/ipykernel_479014/84920249.py", line 6, in <module>
#
#   File "/home/student/andrewheschl/image-super-resolution/ISR/models/imagemodel.py", line 59, in predict
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 508, in predict
#
#   File "/home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py", line 208, in one_step_on_data_distributed
#
# Couldn't find ptxas. The following locations were considered: ./cuda_sdk_lib/bin/ptxas, /home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/bin/ptxas, /home/student/andrewheschl/anaconda3/bin/ptxas, /home/student/andrewheschl/anaconda3/condabin/ptxas, /usr/local/sbin/ptxas, /usr/local/bin/ptxas, /usr/sbin/ptxas, /usr/bin/ptxas, /sbin/ptxas, /bin/ptxas, /usr/games/ptxas, /usr/local/games/ptxas, /snap/bin/ptxas, /usr/local/cuda-12.3/bin/ptxas, /usr/local/cuda/bin/ptxas, /home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/tensorflow/python/platform/../../../nvidia/cuda_nvcc/bin/ptxas, /home/student/andrewheschl/Documents/Diffusion_ClasSeg/.env/lib/python3.11/site-packages/tensorflow/python/platform/../../../../nvidia/cuda_nvcc/bin/ptxas
# 	 [[{{node StatefulPartitionedCall}}]] [Op:__inference_one_step_on_data_distributed_11181]
